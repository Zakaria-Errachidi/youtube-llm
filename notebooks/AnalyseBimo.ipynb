# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Informations relatives aux tableaux.csv")
print("Fusion terminée !")
print("Nombre total de lignes :", df.shape[0])
print("Nombre total de colonnes :", df.shape[1])
# Out:
# Fusion terminée !
# Nombre total de lignes : 451
# Nombre total de colonnes : 12
